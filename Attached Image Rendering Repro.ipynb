# %% [markdown]
# ### Image Attached

# %% [markdown]
# This is an image attachment inside markdown cell.
#
# ![Screenshot 2022-04-21 at 11.42.22 AM.png](attachment:c4f42b38-d8df-45b6-ba91-020b42bcf12d.png)
#
#
# Some trailing markdown text
# - A
# - Small
# - List
#
#
# #### Another attachement in the same markdown cell
#
# ![Screenshot 2022-04-21 at 11.59.51 AM.png](attachment:35aa520e-9ebf-403d-a772-3121492b7cf0.png)
